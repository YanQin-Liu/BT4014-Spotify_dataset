# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("./Original csv/spotify_dataset_gigasheet.csv")
df
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20589  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20590  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20591  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20592  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20593  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                      Plastic Beach      album         0.689
# 4                                           Gorillaz      album         0.663
# ...                                              ...        ...           ...
# 20589                           JUST DANCE HARDSTYLE     single         0.582
# 20590                 SET FIRE TO THE RAIN HARDSTYLE     single         0.531
# 20591                      OUTSIDE HARDSTYLE SPED UP     single         0.443
# 20592                            ONLY GIRL HARDSTYLE     single         0.417
# 20593                             MISS YOU HARDSTYLE     single         0.498
#
#        Energy  Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 0       0.705    -6.679       0.1770      0.008360          0.002330  ...
# 1       0.703    -5.815       0.0302      0.086900          0.000687  ...
# 2       0.923    -3.930       0.0522      0.042500          0.046900  ...
# 3       0.739    -5.810       0.0260      0.000015          0.509000  ...
# 4       0.694    -8.627       0.1710      0.025300          0.000000  ...
# ...       ...       ...          ...           ...               ...  ...
# 20589   0.926    -6.344       0.0328      0.448000          0.000000  ...
# 20590   0.936    -1.786       0.1370      0.028000          0.000000  ...
# 20591   0.830    -4.679       0.0647      0.024300          0.000000  ...
# 20592   0.767    -4.004       0.4190      0.356000          0.018400  ...
# 20593   0.938    -4.543       0.1070      0.002770          0.911000  ...
#
#                                                    Title              Channel  \
# 0             Gorillaz - Feel Good Inc. (Official Video)             Gorillaz
# 1      Gorillaz - Rhinestone Eyes [Storyboard Film] (...             Gorillaz
# 2      Gorillaz - New Gold ft. Tame Impala & Bootie B...             Gorillaz
# 3         Gorillaz - On Melancholy Hill (Official Video)             Gorillaz
# 4             Gorillaz - Clint Eastwood (Official Video)             Gorillaz
# ...                                                  ...                  ...
# 20589                               JUST DANCE HARDSTYLE  SICK LEGEND - Topic
# 20590                     SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic
# 20591                          OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic
# 20592                                ONLY GIRL HARDSTYLE  SICK LEGEND - Topic
# 20593                                 MISS YOU HARDSTYLE  SICK LEGEND - Topic
#
#            Views    Likes Comments Licensed  official_video      Stream  \
# 0      693555221  6220896   169907     True            True  1040234854
# 1       72011645  1079128    31003     True            True   310083733
# 2        8435055   282142     7399     True            True    63063467
# 3      211754952  1788577    55229     True            True   434663559
# 4      618480958  6197318   155930     True            True   617259738
# ...          ...      ...      ...      ...             ...         ...
# 20589      71678     1113        0     True            True     9227144
# 20590     164741     2019        0     True            True    10898176
# 20591      35646      329        0     True            True     6226110
# 20592       6533       88        0     True            True     6873961
# 20593     158697     2484        0     True            True     5695584
#
#        EnergyLiveness  most_playedon
# 0            1.150082        Spotify
# 1           15.183585        Spotify
# 2            7.956897        Spotify
# 3           11.546875        Spotify
# 4            9.942693        Youtube
# ...               ...            ...
# 20589       11.036949        Spotify
# 20590       10.140845        Spotify
# 20591        5.389610        Spotify
# 20592        7.101852        Spotify
# 20593        6.897059        Spotify
#
# [20594 rows x 24 columns]

# %%
print((df['Title'] == 'None').sum())
df.isna().sum()
# Out:
# 0
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_min        0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# EnergyLiveness      0
# most_playedon       0
# dtype: int64

# %%
df = df.sort_values('Stream', ascending=False)
df.duplicated(subset=['Artist', 'Track']).value_counts()
# Out:
# False    20512
# True        82
# dtype: int64

# %%
numerical_cols = df.select_dtypes(include='number').columns
zero_counts = (df[numerical_cols] == 0).sum()
print(zero_counts)
# Out:
# Danceability          19
# Energy                 2
# Loudness               2
# Speechiness           19
# Acousticness           2
# Instrumentalness    9319
# Liveness               2
# Valence               28
# Tempo                 19
# Duration_min           2
# Views                470
# Likes                557
# Comments            1065
# Stream               576
# EnergyLiveness         2
# dtype: int64

# %%
# remove duplicate artist/track combos
df = df.drop_duplicates(subset=['Artist', 'Track'], keep='first')

#remove rows with zero tempo and duration
df = df[(df['Tempo'] != 0) & (df['Duration_min'] != 0)].copy()

# set flag for zero views and streams
df['zero_engagement_flag'] = (df['Views'] == 0) | (df['Stream'] == 0)
df
# Out:
#                    Artist                                          Track  \
# 15166          The Weeknd                                Blinding Lights
# 12385          Ed Sheeran                                   Shape of You
# 19082       Lewis Capaldi                              Someone You Loved
# 17847         Post Malone                     rockstar (feat. 21 Savage)
# 17356            Swae Lee  Sunflower - Spider-Man: Into the Spider-Verse
# ...                   ...                                            ...
# 1127          Soda Stereo                               De Música Ligera
# 3999          Deep Purple                           Burn - 2002 Remaster
# 3998          Deep Purple                                           Hush
# 11590       Ramin Djawadi    Main Title (From Game of Thrones: Season 6)
# 2935   Conjunto Primavera                                     Algo De Mí
#
#                                                    Album Album_type  \
# 15166                                        After Hours      album
# 12385                                         ÷ (Deluxe)      album
# 19082            Divinely Uninspired To A Hellish Extent      album
# 17847                               beerbongs & bentleys      album
# 17356                               Hollywood's Bleeding      album
# ...                                                  ...        ...
# 1127                              Originales - 20 Exitos      album
# 3999                       Burn (Expanded 2005 Remaster)      album
# 3998                               Shades of Deep Purple      album
# 11590  Game Of Thrones: Season 6 (Music from the HBO ...      album
# 2935                                          Algo De Mi      album
#
#        Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 15166         0.514   0.730    -5.934       0.0598       0.00146
# 12385         0.825   0.652    -3.183       0.0802       0.58100
# 19082         0.501   0.405    -5.679       0.0319       0.75100
# 17847         0.585   0.520    -6.136       0.0712       0.12400
# 17356         0.755   0.522    -4.368       0.0575       0.53300
# ...             ...     ...       ...          ...           ...
# 1127          0.542   0.714    -8.045       0.0280       0.00487
# 3999          0.380   0.938    -6.183       0.0384       0.01090
# 3998          0.577   0.664    -9.153       0.0461       0.00533
# 11590         0.194   0.695   -10.809       0.0578       0.17600
# 2935          0.651   0.807    -2.437       0.0327       0.45700
#
#        Instrumentalness  ...               Channel       Views     Likes  \
# 15166          0.000095  ...         TheWeekndVEVO   674164500   8817927
# 12385          0.000000  ...            Ed Sheeran  5908398479  31047780
# 19082          0.000000  ...      LewisCapaldiVEVO   586768373   7367091
# 17847          0.000070  ...        PostMaloneVEVO  1060220169  12564657
# 17356          0.000000  ...        PostMaloneVEVO  1977389027  13749806
# ...                 ...  ...                   ...         ...       ...
# 1127           0.298000  ...        SodaStereoVEVO   109583271    984734
# 3999           0.025700  ...              shotguy1    23323708    118306
# 3998           0.111000  ...        DeepPurpleVEVO    12464310     46986
# 11590          0.893000  ...        Game of Themes    56957541    380796
# 2935           0.000000  ...  ConjuntoPrimavraVEVO    64374531    176912
#
#        Comments Licensed official_video      Stream  EnergyLiveness  \
# 15166    282589     True           True  3386520288        8.138239
# 12385   1130327     True           True  3362005201        7.003222
# 19082    147565     True           True  2634013335        3.857143
# 17847    366520     True           True  2594926619        3.969466
# 17356    331064     True           True  2538329799        7.620438
# ...         ...      ...            ...         ...             ...
# 1127      18767     True           True           0        2.137725
# 3999       6577    False          False           0        2.562842
# 3998       1653     True           True           0        4.676056
# 11590     20483    False          False           0        5.791667
# 2935       4931     True           True           0        3.771028
#
#        most_playedon  zero_engagement_flag
# 15166        Spotify                 False
# 12385        Youtube                 False
# 19082        Spotify                 False
# 17847        Spotify                 False
# 17356        Spotify                 False
# ...              ...                   ...
# 1127         Youtube                  True
# 3999         Youtube                  True
# 3998         Youtube                  True
# 11590        Youtube                  True
# 2935         Youtube                  True
#
# [20493 rows x 25 columns]

# %%
df.to_csv('spotify_cleaned.csv', index=False)
