# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("./spotify_cleaned.csv")
df
df.sort_values(by='Duration_min')
df['Album_type'].value_counts()
# Out:
# album     14749
# single     4926
# Name: Album_type, dtype: int64

# %%
# 7 taste profile features only — aligned with independence_tests.ipynb results
# Dropped: Loudness (redundant with Energy, MI=0.643), Liveness (weak taste signal),
#          Duration_min (not taste), EnergyLiveness (engineered/redundant)
features = [
    'Danceability', 'Energy', 'Valence', 'Acousticness',
    'Instrumentalness', 'Speechiness', 'Tempo'
]
X = df[features]
X

# %%
# scale each column to have mean 0 and sd = 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df['cluster5'] = kmeans.fit_predict(X_scaled)

centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=features)
print(centers)
centers.to_csv('./K-means/cluster5.csv', index=False)
# Out:
#    Danceability   Loudness       Tempo  Speechiness  Acousticness  \
# 0      0.703502  -5.993187  121.600561     0.074132      0.178495
# 1      0.521015  -8.759084  118.560162     0.051945      0.427099
# 2      0.631194  -6.006546  123.230216     0.079845      0.200842
# 3      0.712942  -7.372049  124.679846     0.350921      0.248472
# 4      0.357463 -21.088595  108.383335     0.048600      0.775239
#
#    Instrumentalness  Liveness   Valence  Duration_min  EnergyLiveness
# 0          0.023625  0.105527  0.674405      3.536843        8.293789
# 1          0.023001  0.147071  0.349285      4.009833        4.086561
# 2          0.019606  0.445484  0.606520      3.617467        1.940788
# 3          0.007309  0.187586  0.532058      3.379526        4.680437
# 4          0.804491  0.145062  0.196840      3.309848        1.922594

# %%
kmeans = KMeans(n_clusters=10, random_state=42)
df['cluster10'] = kmeans.fit_predict(X_scaled)

centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=features)
print(centers)
centers.to_csv('./K-means/cluster10.csv', index=False)
# Out:
#    Danceability   Loudness       Tempo  Speechiness  Acousticness  \
# 0      0.602388  -6.269385  110.870178     0.065155      0.125768
# 1      0.742504  -6.204974  112.549543     0.074681      0.231823
# 2      0.523244 -10.972452  111.293787     0.046840      0.720371
# 3      0.585448  -8.689458  124.962232     0.061130      0.221016
# 4      0.599269  -6.292939  121.644288     0.095517      0.275547
# 5      0.294488 -24.674626  103.311365     0.046399      0.900340
# 6      0.704772  -5.450761  121.093470     0.085861      0.130985
# 7      0.719661  -7.733154  118.333323     0.386710      0.262067
# 8      0.583292  -8.008013  117.133864     0.074267      0.273110
# 9      0.533383  -6.105982  167.022483     0.095407      0.195652
#
#    Instrumentalness  Liveness   Valence  Duration_min  EnergyLiveness
# 0          0.009136  0.167613  0.337826      3.635218        5.015018
# 1          0.005682  0.171218  0.742321      3.350790        5.122581
# 2          0.018002  0.150323  0.366247      3.557823        2.948993
# 3          0.732411  0.162263  0.438880      3.716598        5.635589
# 4          0.013309  0.684124  0.574735      3.650778        1.123323
# 5          0.837260  0.141402  0.148168      3.220922        1.019998
# 6          0.016831  0.058716  0.709840      3.652595       14.819508
# 7          0.002950  0.197078  0.536674      3.261700        4.561511
# 8          0.024748  0.170881  0.505845      6.006676        4.972405
# 9          0.009221  0.175025  0.570281      3.553729        5.297891

# %%
kmeans = KMeans(n_clusters=15, random_state=42)
df['cluster15'] = kmeans.fit_predict(X_scaled)

centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=features)
print(centers)
centers.to_csv('./K-means/cluster15.csv', index=False)
# Out:
#     Danceability   Loudness       Tempo  Speechiness  Acousticness  \
# 0       0.605056  -5.945503  169.968934     0.113600      0.227312
# 1       0.466458 -11.752119   89.502225     0.044863      0.727327
# 2       0.739258  -6.958269  119.205786     0.324664      0.220794
# 3       0.295881 -24.698877  103.657407     0.046422      0.900621
# 4       0.633635  -6.384530  104.917381     0.064876      0.141417
# 5       0.687859  -5.412332  122.653072     0.087942      0.124227
# 6       0.583501  -6.382664  123.317566     0.104314      0.308606
# 7       0.510192  -9.970783  143.517344     0.047850      0.676485
# 8       0.699965  -8.175484  110.959515     0.064863      0.592043
# 9       0.635756 -14.301281  107.175948     0.868044      0.468625
# 10      0.753181  -5.964437  112.799608     0.071642      0.143908
# 11      0.449802  -6.028111  149.312224     0.066034      0.090320
# 12      0.688516  -5.745111  114.324048     0.073795      0.129136
# 13      0.587747  -8.654796  124.912079     0.061562      0.217446
# 14      0.593075  -8.154195  114.397671     0.078969      0.281602
#
#     Instrumentalness  Liveness   Valence  Duration_min  EnergyLiveness
# 0           0.007191  0.151396  0.723205      3.388866        6.178800
# 1           0.025252  0.159002  0.300923      3.574780        2.566768
# 2           0.002459  0.165839  0.522547      3.303974        5.040141
# 3           0.843150  0.140557  0.147917      3.206520        1.024747
# 4           0.009268  0.137325  0.342253      3.556267        5.615449
# 5           0.022262  0.047873  0.711598      3.678233       18.417003
# 6           0.013632  0.747879  0.564754      3.679642        1.001675
# 7           0.015128  0.146176  0.335380      3.823448        3.276709
# 8           0.008073  0.154494  0.705091      3.158438        4.239517
# 9           0.000113  0.403665  0.553091      2.937653        1.616279
# 10          0.007113  0.101159  0.742862      3.497931        7.810308
# 11          0.013647  0.183641  0.337276      3.993037        5.043047
# 12          0.006850  0.330255  0.662784      3.523238        2.436093
# 13          0.737182  0.161545  0.441877      3.702649        5.694275
# 14          0.028993  0.165580  0.520421      6.257184        5.173970

# %%
kmeans = KMeans(n_clusters=20, random_state=42)
df['cluster20'] = kmeans.fit_predict(X_scaled)

centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=features)
print(centers)
centers.to_csv('./K-means/cluster20.csv', index=False)
# Out:
#     Danceability   Loudness       Tempo  Speechiness  Acousticness  \
# 0       0.457704  -6.135040  151.135859     0.061576      0.094978
# 1       0.719055  -6.939417   96.225772     0.322018      0.245790
# 2       0.710788  -5.643215  112.125293     0.074706      0.147873
# 3       0.503773  -9.956007  142.611712     0.045730      0.678108
# 4       0.294475 -24.748836  103.623403     0.046352      0.900748
# 5       0.513393  -5.591749  150.389586     0.077909      0.106971
# 6       0.497511  -6.645653   92.106467     0.054775      0.156228
# 7       0.468972 -12.297014   90.170307     0.044728      0.767883
# 8       0.635225 -14.542938  105.908705     0.878488      0.474672
# 9       0.727414  -6.272286  116.829890     0.078934      0.147605
# 10      0.714291  -6.611043  158.222714     0.322482      0.204888
# 11      0.691740  -8.067076  111.777817     0.060885      0.246412
# 12      0.589006  -8.723474  125.035753     0.061750      0.219113
# 13      0.604282  -6.066832  167.448668     0.079048      0.254275
# 14      0.710699  -5.069738  126.748476     0.089528      0.106182
# 15      0.590366  -6.438706  119.433922     0.100694      0.326946
# 16      0.526087  -8.758025  118.861192     0.089550      0.313779
# 17      0.698672  -5.400947  118.696812     0.084410      0.127163
# 18      0.690234  -8.415379  111.867795     0.062728      0.635411
# 19      0.756410  -5.853538  111.444358     0.072557      0.152030
#
#     Instrumentalness  Liveness   Valence  Duration_min  EnergyLiveness
# 0           0.014554  0.124587  0.328492      4.008631        6.431606
# 1           0.001989  0.181143  0.543720      3.485128        4.819489
# 2           0.006005  0.333895  0.704971      3.446445        2.408012
# 3           0.014246  0.140349  0.324483      3.932853        3.335810
# 4           0.845776  0.139923  0.147636      3.191035        1.022914
# 5           0.012615  0.370544  0.480209      3.641802        2.219521
# 6           0.012089  0.159633  0.347734      3.964152        5.038732
# 7           0.027782  0.159619  0.296039      3.477623        2.365507
# 8           0.000118  0.412491  0.547382      2.905107        1.541984
# 9           0.009106  0.140493  0.347785      3.264726        5.380821
# 10          0.003748  0.157179  0.548740      3.224552        5.356705
# 11          0.015167  0.132478  0.657572      5.025062        5.954209
# 12          0.744526  0.162285  0.439461      3.672146        5.652761
# 13          0.007297  0.130254  0.771513      3.440813        6.666642
# 14          0.054961  0.027866  0.754282      3.553276       31.904911
# 15          0.011623  0.765081  0.571590      3.690708        0.968471
# 16          0.054113  0.197621  0.432916      7.445438        4.371444
# 17          0.014850  0.056447  0.694656      3.661348       14.708438
# 18          0.009528  0.156884  0.681365      3.045796        4.004595
# 19          0.006711  0.107669  0.765606      3.258141        7.207893
